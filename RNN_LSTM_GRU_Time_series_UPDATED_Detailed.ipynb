# %%
# ============================
# NIFTY Price Prediction Teaching Notebook
# RNN / LSTM / GRU — many variants, visuals & comparisons
# Simplified version without functions for easier teaching
# ============================

# Import necessary libraries for data manipulation, visualization, and machine learning
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time, math
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.seasonal import seasonal_decompose
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, SimpleRNN, LSTM, GRU
from tensorflow.keras.callbacks import EarlyStopping

# -----------------------
# Reproducibility - Set random seeds for consistent results
# -----------------------
# Set numpy random seed for reproducible results
SEED = 42
np.random.seed(SEED)
# Set tensorflow random seed for reproducible neural network initialization
tf.random.set_seed(SEED)

# -----------------------
# Configuration - Parameters that can be adjusted for different experiments
# -----------------------
# Define the stock ticker symbol for NIFTY 50 index
TICKER = "^NSEI"
# Start date for historical data
START_DATE = "2010-01-01"
# End date (None means up to current date)
END_DATE = None
# Features to use for prediction (can be expanded to include Open, High, Low, Volume)
USE_FEATURES = ["Close"]
# Number of previous time steps to use for predicting the next value
TIME_STEPS = 60
# Proportion of data to use for testing
TEST_SPLIT = 0.2
# Number of recent days to show in visualization
VIZ_SAMPLE_DAYS = 1000
# Number of training iterations
EPOCHS = 20
# Number of samples per gradient update
BATCH_SIZE = 32

# -----------------------
# 1) Download Data - Get historical stock price data
# -----------------------
# Print status message
print("Downloading data for", TICKER)
# Download historical data using yfinance library
df = yf.download(TICKER, start=START_DATE, end=END_DATE, progress=False)
# Check if data was successfully downloaded
if df.empty:
    raise RuntimeError("No data downloaded. Check ticker or date range.")
# Reset index to make Date a column instead of index
df = df.reset_index()
# Convert Date column to datetime format
df['Date'] = pd.to_datetime(df['Date'])
# Sort data by date to ensure chronological order
df = df.sort_values('Date').reset_index(drop=True)
# Print data shape and first few rows
print("Data downloaded:", df.shape)
print(df.head())

# -----------------------
# Visualize Data - Create plots to understand data patterns
# -----------------------
# Create figure for full price history
plt.figure(figsize=(14,5))
# Plot closing prices over time
plt.plot(df['Date'], df['Close'], lw=1)
# Add title and labels
plt.title("NIFTY — Closing Price (full range)")
plt.xlabel("Date"); plt.ylabel("Close Price")
# Display the plot
plt.show()

# Create figure for recent price history
plt.figure(figsize=(14,5))
# Plot only the most recent days for detailed view
plt.plot(df['Date'].iloc[-VIZ_SAMPLE_DAYS:], df['Close'].iloc[-VIZ_SAMPLE_DAYS:], lw=1)
# Add title and labels
plt.title(f"NIFTY — Closing Price (last {VIZ_SAMPLE_DAYS} days)")
plt.xlabel("Date"); plt.ylabel("Close Price")
# Display the plot
plt.show()

# -----------------------
# 2) Seasonal Decomposition - Break down time series into components
# -----------------------
try:
    # Set decomposition period to approximate trading days in a year
    decomp_period = 252
    # Decompose time series into trend, seasonal, and residual components
    decomposed = seasonal_decompose(df['Close'], period=decomp_period, model='multiplicative', extrapolate_trend='freq')
    # Create decomposition plot
    fig = decomposed.plot()
    # Adjust plot size
    fig.set_size_inches(14,10)
    # Add title
    plt.suptitle("Seasonal Decompose (multiplicative)")
    # Display the plot
    plt.show()
except Exception as e:
    # Print error message if decomposition fails
    print("Seasonal decomposition skipped:", e)

# -----------------------
# 3) Preprocessing - Prepare data for machine learning
# -----------------------
# Copy feature list to avoid modifying original
features = USE_FEATURES.copy()
# Extract feature values as numpy array
data = df[features].astype('float32').values
# Print which features are being used
print("Using features:", features)

# Create scaler object for normalizing data between 0 and 1
scaler = MinMaxScaler(feature_range=(0,1))
# Fit scaler to data and transform data to scaled version
data_scaled = scaler.fit_transform(data)
# Print shape of scaled data
print("Scaled data shape:", data_scaled.shape)

# -----------------------
# 4) Create Sequences - Convert time series to supervised learning format
# -----------------------
# Initialize empty lists for features (X) and targets (y)
X, y = [], []
# Loop through data to create sequences
for i in range(TIME_STEPS, len(data_scaled)):
    # Add sequence of TIME_STEPS previous values as features
    X.append(data_scaled[i-TIME_STEPS:i])
    # Add next value as target
    y.append(data_scaled[i])
# Convert lists to numpy arrays
X = np.array(X)
y = np.array(y)
# Print shapes of created sequences
print("Sequence shapes X, y:", X.shape, y.shape)

# Show example window from the dataset
# Select a sample index near the end of the dataset
sample_idx = -100
# Inverse transform to get original scale values and take first 10
example_window = scaler.inverse_transform(X[sample_idx].reshape(-1, X.shape[-1])).flatten()[:10]
# Print the example window
print("\nExample window (first 10 values in original scale):")
print(example_window)

# -----------------------
# 5) Train-test split - Split data into training and testing sets
# -----------------------
# Calculate split index based on TEST_SPLIT ratio
split_idx = int((1 - TEST_SPLIT) * len(X))
# Split features into training and testing sets
X_train, X_test = X[:split_idx], X[split_idx:]
# Split targets into training and testing sets
y_train, y_test = y[:split_idx], y[split_idx:]
# Print shapes of training and testing data
print("Train shape:", X_train.shape, "Test shape:", X_test.shape)

# -----------------------
# 6) Model Building - Explicit and Repetitive model creation
# -----------------------
# Get number of features from input data shape
n_features = X.shape[-1]
# Define early stopping callback to prevent overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# RNN Models - Simple Recurrent Neural Networks

# Build RNN with 32 units
print("\n" + "="*50)
print("Building RNN-32")
# Create sequential model
model_rnn_32 = Sequential()
# Add SimpleRNN layer with 32 units and specify input shape
model_rnn_32.add(SimpleRNN(32, input_shape=(TIME_STEPS, n_features)))
# Add dropout layer for regularization
model_rnn_32.add(Dropout(0.1))
# Add output layer with same number of units as features
model_rnn_32.add(Dense(n_features))
# Compile model with Adam optimizer and MSE loss
model_rnn_32.compile(optimizer='adam', loss='mse', metrics=['mae'])
# Print model architecture summary
print(model_rnn_32.summary())

# Build RNN with 64->32 units
print("\n" + "="*50)
print("Building RNN-64-32")
# Create sequential model
model_rnn_64_32 = Sequential()
# Add first RNN layer with 64 units, return sequences for stacking
model_rnn_64_32.add(SimpleRNN(64, return_sequences=True, input_shape=(TIME_STEPS, n_features)))
# Add dropout
model_rnn_64_32.add(Dropout(0.2))
# Add second RNN layer with 32 units
model_rnn_64_32.add(SimpleRNN(32))
# Add dropout
model_rnn_64_32.add(Dropout(0.2))
# Add output layer
model_rnn_64_32.add(Dense(n_features))
# Compile model
model_rnn_64_32.compile(optimizer='adam', loss='mse', metrics=['mae'])
# Print model summary
print(model_rnn_64_32.summary())

# Build RNN with 128->64->32 units
print("\n" + "="*50)
print("Building RNN-128-64-32")
# Create sequential model
model_rnn_128_64_32 = Sequential()
# Add first RNN layer with 128 units
model_rnn_128_64_32.add(SimpleRNN(128, return_sequences=True, input_shape=(TIME_STEPS, n_features)))
# Add dropout
model_rnn_128_64_32.add(Dropout(0.3))
# Add second RNN layer with 64 units
model_rnn_128_64_32.add(SimpleRNN(64, return_sequences=True))
# Add dropout
model_rnn_128_64_32.add(Dropout(0.3))
# Add third RNN layer with 32 units
model_rnn_128_64_32.add(SimpleRNN(32))
# Add dropout
model_rnn_128_64_32.add(Dropout(0.3))
# Add output layer
model_rnn_128_64_32.add(Dense(n_features))
# Compile model
model_rnn_128_64_32.compile(optimizer='adam', loss='mse', metrics=['mae'])
# Print model summary
print(model_rnn_128_64_32.summary())

# LSTM Models - Long Short-Term Memory networks

# Build LSTM with 32 units
print("\n" + "="*50)
print("Building LSTM-32")
# Create sequential model
model_lstm_32 = Sequential()
# Add LSTM layer with 32 units
model_lstm_32.add(LSTM(32, input_shape=(TIME_STEPS, n_features)))
# Add dropout
model_lstm_32.add(Dropout(0.1))
# Add output layer
model_lstm_32.add(Dense(n_features))
# Compile model
model_lstm_32.compile(optimizer='adam', loss='mse', metrics=['mae'])
# Print model summary
print(model_lstm_32.summary())

# Build LSTM with 64->32 units
print("\n" + "="*50)
print("Building LSTM-64-32")
# Create sequential model
model_lstm_64_32 = Sequential()
# Add first LSTM layer with 64 units
model_lstm_64_32.add(LSTM(64, return_sequences=True, input_shape=(TIME_STEPS, n_features)))
# Add dropout
model_lstm_64_32.add(Dropout(0.2))
# Add second LSTM layer with 32 units
model_lstm_64_32.add(LSTM(32))
# Add dropout
model_lstm_64_32.add(Dropout(0.2))
# Add output layer
model_lstm_64_32.add(Dense(n_features))
# Compile model
model_lstm_64_32.compile(optimizer='adam', loss='mse', metrics=['mae'])
# Print model summary
print(model_lstm_64_32.summary())

# Build LSTM with 128->64->32 units
print("\n" + "="*50)
print("Building LSTM-128-64-32")
# Create sequential model
model_lstm_128_64_32 = Sequential()
# Add first LSTM layer with 128 units
model_lstm_128_64_32.add(LSTM(128, return_sequences=True, input_shape=(TIME_STEPS, n_features)))
# Add dropout
model_lstm_128_64_32.add(Dropout(0.3))
# Add second LSTM layer with 64 units
model_lstm_128_64_32.add(LSTM(64, return_sequences=True))
# Add dropout
model_lstm_128_64_32.add(Dropout(0.3))
# Add third LSTM layer with 32 units
model_lstm_128_64_32.add(LSTM(32))
# Add dropout
model_lstm_128_64_32.add(Dropout(0.3))
# Add output layer
model_lstm_128_64_32.add(Dense(n_features))
# Compile model
model_lstm_128_64_32.compile(optimizer='adam', loss='mse', metrics=['mae'])
# Print model summary
print(model_lstm_128_64_32.summary())

# GRU Models - Gated Recurrent Units

# Build GRU with 32 units
print("\n" + "="*50)
print("Building GRU-32")
# Create sequential model
model_gru_32 = Sequential()
# Add GRU layer with 32 units
model_gru_32.add(GRU(32, input_shape=(TIME_STEPS, n_features)))
# Add dropout
model_gru_32.add(Dropout(0.1))
# Add output layer
model_gru_32.add(Dense(n_features))
# Compile model
model_gru_32.compile(optimizer='adam', loss='mse', metrics=['mae'])
# Print model summary
print(model_gru_32.summary())

# Build GRU with 64->32 units
print("\n" + "="*50)
print("Building GRU-64-32")
# Create sequential model
model_gru_64_32 = Sequential()
# Add first GRU layer with 64 units
model_gru_64_32.add(GRU(64, return_sequences=True, input_shape=(TIME_STEPS, n_features)))
# Add dropout
model_gru_64_32.add(Dropout(0.2))
# Add second GRU layer with 32 units
model_gru_64_32.add(GRU(32))
# Add dropout
model_gru_64_32.add(Dropout(0.2))
# Add output layer
model_gru_64_32.add(Dense(n_features))
# Compile model
model_gru_64_32.compile(optimizer='adam', loss='mse', metrics=['mae'])
# Print model summary
print(model_gru_64_32.summary())

# Build GRU with 128->64->32 units
print("\n" + "="*50)
print("Building GRU-128-64-32")
# Create sequential model
model_gru_128_64_32 = Sequential()
# Add first GRU layer with 128 units
model_gru_128_64_32.add(GRU(128, return_sequences=True, input_shape=(TIME_STEPS, n_features)))
# Add dropout
model_gru_128_64_32.add(Dropout(0.3))
# Add second GRU layer with 64 units
model_gru_128_64_32.add(GRU(64, return_sequences=True))
# Add dropout
model_gru_128_64_32.add(Dropout(0.3))
# Add third GRU layer with 32 units
model_gru_128_64_32.add(GRU(32))
# Add dropout
model_gru_128_64_32.add(Dropout(0.3))
# Add output layer
model_gru_128_64_32.add(Dense(n_features))
# Compile model
model_gru_128_64_32.compile(optimizer='adam', loss='mse', metrics=['mae'])
# Print model summary
print(model_gru_128_64_32.summary())

# -----------------------
# 7) Train all models - Train each model and record performance
# -----------------------
# Create dictionary to store all models
models = {
    "RNN-32": model_rnn_32,
    "RNN-64-32": model_rnn_64_32,
    "RNN-128-64-32": model_rnn_128_64_32,
    "LSTM-32": model_lstm_32,
    "LSTM-64-32": model_lstm_64_32,
    "LSTM-128-64-32": model_lstm_128_64_32,
    "GRU-32": model_gru_32,
    "GRU-64-32": model_gru_64_32,
    "GRU-128-64-32": model_gru_128_64_32
}

# Initialize dictionaries to store training results
history = {}
results = {}
timings = {}
predictions = {}

# Loop through each model for training and evaluation
for name, model in models.items():
    # Print separator and model name
    print("\n" + "="*50)
    print("Training model:", name)

    # Record start time for training
    start = time.time()
    # Train the model on training data
    h = model.fit(
        X_train, y_train,
        validation_split=0.15,  # Use 15% of training data for validation
        epochs=EPOCHS,          # Number of training iterations
        batch_size=BATCH_SIZE,  # Samples per gradient update
        callbacks=[early_stop], # Early stopping callback
        verbose=1               # Show training progress
    )
    # Calculate training time
    elapsed = time.time() - start

    # Make predictions on test data
    y_pred_scaled = model.predict(X_test)
    # Convert scaled predictions back to original price scale
    y_test_rescaled = scaler.inverse_transform(y_test)
    y_pred_rescaled = scaler.inverse_transform(y_pred_scaled)

    # Find index of Close price in features (for evaluation)
    close_idx = features.index("Close") if "Close" in features else 0
    # Calculate Root Mean Squared Error
    rmse = math.sqrt(mean_squared_error(y_test_rescaled[:, close_idx], y_pred_rescaled[:, close_idx]))
    # Calculate Mean Absolute Error
    mae = mean_absolute_error(y_test_rescaled[:, close_idx], y_pred_rescaled[:, close_idx])

    # Print model performance metrics
    print(f"{name} RMSE (Close): {rmse:.4f}, MAE (Close): {mae:.4f}, Time: {elapsed:.1f}s")

    # Store results in dictionaries
    history[name] = h
    results[name] = {"rmse": rmse, "mae": mae}
    timings[name] = elapsed
    predictions[name] = {"y_true": y_test_rescaled[:, close_idx], "y_pred": y_pred_rescaled[:, close_idx]}

# -----------------------
# 8) Visual Comparisons - Create plots to compare model performance
# -----------------------
# Create plot for validation loss comparison
plt.figure(figsize=(14,6))
# Plot validation loss for each model
for name, h in history.items():
    if "val_loss" in h.history:
        plt.plot(h.history['val_loss'], label=name)
# Add plot title and labels
plt.title("Validation Loss (MSE) per Model Variant")
plt.xlabel("Epoch")
plt.ylabel("Val Loss")
# Add legend
plt.legend()
# Display plot
plt.show()

# Create plot for validation MAE comparison
plt.figure(figsize=(14,6))
# Plot validation MAE for each model
for name, h in history.items():
    if "val_mae" in h.history:
        plt.plot(h.history['val_mae'], label=name)
# Add plot title and labels
plt.title("Validation MAE per Model Variant")
plt.xlabel("Epoch")
plt.ylabel("Val MAE")
# Add legend
plt.legend()
# Display plot
plt.show()

# Create runtime comparison bar chart
plt.figure(figsize=(10,6))
# Get model names and training times
names = list(timings.keys())
times = [timings[n] for n in names]
# Create bar plot
sns.barplot(x=times, y=names)
# Add labels and title
plt.xlabel("Training Time (s)")
plt.title("Training Time per Model Variant")
# Display plot
plt.show()

# -----------------------
# 9) Show predictions for best model - Detailed analysis of best performing model
# -----------------------
# Find model with lowest RMSE
best_name = min(results.keys(), key=lambda k: results[k]['rmse'])
# Print best model information
print("\nBest model by RMSE (Close):", best_name, results[best_name])

# Get actual and predicted values for best model
y_true = predictions[best_name]['y_true']
y_pred = predictions[best_name]['y_pred']

# Create plot comparing actual vs predicted values
plt.figure(figsize=(14,6))
# Plot actual test values
plt.plot(y_true, label='Actual Close (Test)')
# Plot predicted values
plt.plot(y_pred, label='Predicted Close (Test)')
# Add title and labels
plt.title(f"Actual vs Predicted Close Prices — {best_name}")
plt.xlabel("Test sample index")
plt.ylabel("Price")
# Add legend
plt.legend()
# Display plot
plt.show()

# Create zoomed-in view of predictions
# Determine number of points to show (minimum of 200 or available points)
zoom_n = min(200, len(y_true))
plt.figure(figsize=(14,6))
# Plot last zoom_n actual values
plt.plot(y_true[-zoom_n:], lw=1.5, label='Actual (last points)')
# Plot last zoom_n predicted values
plt.plot(y_pred[-zoom_n:], lw=1.2, label='Predicted (last points)')
# Add title
plt.title(f"Zoom (last {zoom_n}) — {best_name}")
# Add legend
plt.legend()
# Display plot
plt.show()

# -----------------------
# 10) Error analysis - Analyze prediction errors
# -----------------------
# Calculate residuals (prediction errors)
residuals = y_true - y_pred
# Create histogram of residuals
plt.figure(figsize=(10,4))
sns.histplot(residuals, bins=50, kde=True)
# Add title and labels
plt.title(f"Residual Distribution — {best_name}")
plt.xlabel("Residual (Actual - Predicted)")
# Display plot
plt.show()

# -----------------------
# 11) Summary table - Create comprehensive results table
# -----------------------
# Create DataFrame with model performance metrics
summary_df = pd.DataFrame([
    {"Model": name, "RMSE": results[name]['rmse'], "MAE": results[name]['mae'], "Training Time (s)": round(timings[name],1)}
    for name in results
]).sort_values("RMSE")  # Sort by RMSE (ascending - lower is better)
# Print summary table
print("\n=== Summary Table (sorted by RMSE) ===")
print(summary_df)

# -----------------------
# Teaching Notes - Educational guidance for instructors
# -----------------------
print("""
Teaching progression notes:
1) Start with raw plot + decomposition -> motivate stationarity/trend/seasonality.
2) Show the effect of scaling and why sequences are needed.
3) Train small RNN/LSTM/GRU (32 units) — quick results to show model shapes.
4) Increase depth & units (64->32, 128->64->32) and discuss capacity vs overfitting.
5) Show validation loss curves and explain EarlyStopping.
6) Show runtime differences (RNN < GRU < LSTM typically).
7) Demonstrate forecasting quality (RMSE/MAE) and error/residual analysis.

Key concepts to explain:
- Why we use sequential data (time steps)
- How RNN/LSTM/GRU differ in architecture
- The role of dropout in preventing overfitting
- How scaling helps with gradient stability
- Why we use early stopping
- How to interpret RMSE and MAE in context of stock prices
""")
# Out:
# Downloading data for ^NSEI
# /tmp/ipython-input-2421975491.py:59: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(TICKER, start=START_DATE, end=END_DATE, progress=False)
# Data downloaded: (3869, 6)
# Price        Date        Close         High          Low         Open Volume
# Ticker                   ^NSEI        ^NSEI        ^NSEI        ^NSEI  ^NSEI
# 0      2010-01-04  5232.200195  5238.450195  5167.100098  5200.899902      0
# 1      2010-01-05  5277.899902  5288.350098  5242.399902  5277.149902      0
# 2      2010-01-06  5281.799805  5310.850098  5260.049805  5278.149902      0
# 3      2010-01-07  5263.100098  5302.549805  5244.750000  5281.799805      0
# 4      2010-01-08  5244.750000  5276.750000  5234.700195  5264.250000      0
# Using features: ['Close']
# Scaled data shape: (3869, 1)
# Sequence shapes X, y: (3809, 60, 1) (3809, 1)
#
# Example window (first 10 values in original scale):
# [23381.602 23071.803 23045.248 23031.402 22929.25  22959.5   22945.3
#  22932.9   22913.15  22795.9  ]
# Train shape: (3047, 60, 1) Test shape: (762, 60, 1)
#
# ==================================================
# Building RNN-32
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 32)             │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,121 (4.38 KB)
#  Trainable params: 1,121 (4.38 KB)
#  Non-trainable params: 0 (0.00 B)
# None
#
# ==================================================
# Building RNN-64-32
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)        │ (None, 60, 64)         │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_2 (SimpleRNN)        │ (None, 32)             │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,361 (28.75 KB)
#  Trainable params: 7,361 (28.75 KB)
#  Non-trainable params: 0 (0.00 B)
# None
#
# ==================================================
# Building RNN-128-64-32
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_3 (SimpleRNN)        │ (None, 60, 128)        │        16,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 60, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_4 (SimpleRNN)        │ (None, 60, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_5 (SimpleRNN)        │ (None, 32)             │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32,129 (125.50 KB)
#  Trainable params: 32,129 (125.50 KB)
#  Non-trainable params: 0 (0.00 B)
# None
#
# ==================================================
# Building LSTM-32
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 32)             │         4,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,385 (17.13 KB)
#  Trainable params: 4,385 (17.13 KB)
#  Non-trainable params: 0 (0.00 B)
# None
#
# ==================================================
# Building LSTM-64-32
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 60, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)
# None
#
# ==================================================
# Building LSTM-128-64-32
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                   │ (None, 60, 128)        │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 60, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 60, 64)         │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 128,417 (501.63 KB)
#  Trainable params: 128,417 (501.63 KB)
#  Non-trainable params: 0 (0.00 B)
# None
#
# ==================================================
# Building GRU-32
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 32)             │         3,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,393 (13.25 KB)
#  Trainable params: 3,393 (13.25 KB)
#  Non-trainable params: 0 (0.00 B)
# None
#
# ==================================================
# Building GRU-64-32
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_1 (GRU)                     │ (None, 60, 64)         │        12,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 32)             │         9,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,305 (87.13 KB)
#  Trainable params: 22,305 (87.13 KB)
#  Non-trainable params: 0 (0.00 B)
# None
#
# ==================================================
# Building GRU-128-64-32
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_3 (GRU)                     │ (None, 60, 128)        │        50,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 60, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_4 (GRU)                     │ (None, 60, 64)         │        37,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_5 (GRU)                     │ (None, 32)             │         9,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 96,993 (378.88 KB)
#  Trainable params: 96,993 (378.88 KB)
#  Non-trainable params: 0 (0.00 B)
# None
#
# ==================================================
# Training model: RNN-32
# Epoch 1/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - loss: 0.0185 - mae: 0.0896 - val_loss: 0.0146 - val_mae: 0.1159
# Epoch 2/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.5054e-04 - mae: 0.0206 - val_loss: 0.0076 - val_mae: 0.0839
# Epoch 3/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.7738e-04 - mae: 0.0174 - val_loss: 0.0019 - val_mae: 0.0393
# Epoch 4/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.1303e-04 - mae: 0.0165 - val_loss: 5.2203e-04 - val_mae: 0.0190
# Epoch 5/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.3906e-04 - mae: 0.0149 - val_loss: 8.5028e-04 - val_mae: 0.0257
# Epoch 6/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.3468e-04 - mae: 0.0136 - val_loss: 7.9130e-04 - val_mae: 0.0249
# Epoch 7/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.9586e-04 - mae: 0.0125 - val_loss: 6.3683e-04 - val_mae: 0.0224
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# RNN-32 RMSE (Close): 2304.2161, MAE (Close): 2033.3346, Time: 9.1s
#
# ==================================================
# Training model: RNN-64-32
# Epoch 1/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - loss: 0.0345 - mae: 0.1292 - val_loss: 0.0088 - val_mae: 0.0882
# Epoch 2/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0036 - mae: 0.0442 - val_loss: 0.0057 - val_mae: 0.0710
# Epoch 3/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0023 - mae: 0.0356 - val_loss: 0.0030 - val_mae: 0.0502
# Epoch 4/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0017 - mae: 0.0299 - val_loss: 0.0034 - val_mae: 0.0544
# Epoch 5/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0015 - mae: 0.0268 - val_loss: 0.0027 - val_mae: 0.0486
# Epoch 6/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0013 - mae: 0.0255 - val_loss: 0.0021 - val_mae: 0.0428
# Epoch 7/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.5554e-04 - mae: 0.0225 - val_loss: 8.3739e-04 - val_mae: 0.0253
# Epoch 8/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.2711e-04 - mae: 0.0204 - val_loss: 0.0024 - val_mae: 0.0461
# Epoch 9/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.1332e-04 - mae: 0.0190 - val_loss: 0.0017 - val_mae: 0.0383
# Epoch 10/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.3652e-04 - mae: 0.0183 - val_loss: 0.0014 - val_mae: 0.0345
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# RNN-64-32 RMSE (Close): 2332.8734, MAE (Close): 2100.7688, Time: 20.3s
#
# ==================================================
# Training model: RNN-128-64-32
# Epoch 1/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 77ms/step - loss: 0.4679 - mae: 0.5163 - val_loss: 0.0138 - val_mae: 0.1103
# Epoch 2/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0580 - mae: 0.1808 - val_loss: 0.0068 - val_mae: 0.0752
# Epoch 3/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0239 - mae: 0.1141 - val_loss: 0.0024 - val_mae: 0.0412
# Epoch 4/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0128 - mae: 0.0834 - val_loss: 0.0054 - val_mae: 0.0672
# Epoch 5/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0098 - mae: 0.0710 - val_loss: 0.0046 - val_mae: 0.0615
# Epoch 6/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0071 - mae: 0.0605 - val_loss: 0.0041 - val_mae: 0.0593
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# RNN-128-64-32 RMSE (Close): 4270.1297, MAE (Close): 3880.3137, Time: 18.5s
#
# ==================================================
# Training model: LSTM-32
# Epoch 1/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0063 - mae: 0.0552 - val_loss: 0.0011 - val_mae: 0.0272
# Epoch 2/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.3702e-04 - mae: 0.0129 - val_loss: 5.4669e-04 - val_mae: 0.0183
# Epoch 3/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.6831e-04 - mae: 0.0119 - val_loss: 2.1334e-04 - val_mae: 0.0116
# Epoch 4/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.3712e-04 - mae: 0.0108 - val_loss: 2.0198e-04 - val_mae: 0.0115
# Epoch 5/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.1308e-04 - mae: 0.0104 - val_loss: 2.0897e-04 - val_mae: 0.0118
# Epoch 6/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.8954e-04 - mae: 0.0099 - val_loss: 2.3298e-04 - val_mae: 0.0127
# Epoch 7/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.9282e-04 - mae: 0.0099 - val_loss: 4.6997e-04 - val_mae: 0.0191
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# LSTM-32 RMSE (Close): 294.3505, MAE (Close): 230.0459, Time: 8.2s
#
# ==================================================
# Training model: LSTM-64-32
# Epoch 1/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0090 - mae: 0.0642 - val_loss: 6.4496e-04 - val_mae: 0.0215
# Epoch 2/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.5286e-04 - mae: 0.0178 - val_loss: 0.0018 - val_mae: 0.0390
# Epoch 3/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.2268e-04 - mae: 0.0159 - val_loss: 0.0020 - val_mae: 0.0408
# Epoch 4/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.0949e-04 - mae: 0.0160 - val_loss: 0.0010 - val_mae: 0.0285
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# LSTM-64-32 RMSE (Close): 1180.0499, MAE (Close): 1029.8088, Time: 6.0s
#
# ==================================================
# Training model: LSTM-128-64-32
# Epoch 1/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0058 - mae: 0.0519 - val_loss: 0.0018 - val_mae: 0.0379
# Epoch 2/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.9208e-04 - mae: 0.0209 - val_loss: 0.0016 - val_mae: 0.0350
# Epoch 3/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.4340e-04 - mae: 0.0191 - val_loss: 8.1859e-04 - val_mae: 0.0245
# Epoch 4/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.4985e-04 - mae: 0.0181 - val_loss: 0.0029 - val_mae: 0.0499
# Epoch 5/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.9068e-04 - mae: 0.0175 - val_loss: 0.0014 - val_mae: 0.0336
# Epoch 6/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.4677e-04 - mae: 0.0164 - val_loss: 0.0023 - val_mae: 0.0439
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# LSTM-128-64-32 RMSE (Close): 1528.0756, MAE (Close): 1365.1283, Time: 9.2s
#
# ==================================================
# Training model: GRU-32
# Epoch 1/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0110 - mae: 0.0791 - val_loss: 3.6148e-04 - val_mae: 0.0168
# Epoch 2/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.3062e-04 - mae: 0.0127 - val_loss: 1.3563e-04 - val_mae: 0.0091
# Epoch 3/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.1313e-04 - mae: 0.0123 - val_loss: 1.2743e-04 - val_mae: 0.0086
# Epoch 4/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.4821e-04 - mae: 0.0112 - val_loss: 1.1571e-04 - val_mae: 0.0085
# Epoch 5/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.1016e-04 - mae: 0.0105 - val_loss: 1.5189e-04 - val_mae: 0.0103
# Epoch 6/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.1585e-04 - mae: 0.0106 - val_loss: 1.5120e-04 - val_mae: 0.0103
# Epoch 7/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.9267e-04 - mae: 0.0101 - val_loss: 1.7708e-04 - val_mae: 0.0113
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# GRU-32 RMSE (Close): 243.5188, MAE (Close): 189.5193, Time: 6.1s
#
# ==================================================
# Training model: GRU-64-32
# Epoch 1/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0081 - mae: 0.0626 - val_loss: 6.6246e-04 - val_mae: 0.0233
# Epoch 2/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.9469e-04 - mae: 0.0177 - val_loss: 5.1508e-04 - val_mae: 0.0204
# Epoch 3/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.7860e-04 - mae: 0.0168 - val_loss: 6.1757e-04 - val_mae: 0.0225
# Epoch 4/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.6954e-04 - mae: 0.0153 - val_loss: 2.9426e-04 - val_mae: 0.0149
# Epoch 5/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.8867e-04 - mae: 0.0137 - val_loss: 8.1556e-04 - val_mae: 0.0264
# Epoch 6/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.6522e-04 - mae: 0.0134 - val_loss: 4.5311e-04 - val_mae: 0.0191
# Epoch 7/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6852e-04 - mae: 0.0133 - val_loss: 2.1828e-04 - val_mae: 0.0126
# Epoch 8/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.2993e-04 - mae: 0.0126 - val_loss: 1.7419e-04 - val_mae: 0.0111
# Epoch 9/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 2.7890e-04 - mae: 0.0118 - val_loss: 5.1659e-04 - val_mae: 0.0205
# Epoch 10/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.7000e-04 - mae: 0.0114 - val_loss: 1.4055e-04 - val_mae: 0.0097
# Epoch 11/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3076e-04 - mae: 0.0109 - val_loss: 2.8596e-04 - val_mae: 0.0147
# Epoch 12/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3451e-04 - mae: 0.0111 - val_loss: 1.7566e-04 - val_mae: 0.0111
# Epoch 13/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1515e-04 - mae: 0.0105 - val_loss: 1.2689e-04 - val_mae: 0.0091
# Epoch 14/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.2645e-04 - mae: 0.0108 - val_loss: 1.3299e-04 - val_mae: 0.0094
# Epoch 15/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.9638e-04 - mae: 0.0103 - val_loss: 1.5399e-04 - val_mae: 0.0093
# Epoch 16/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.9866e-04 - mae: 0.0102 - val_loss: 3.1333e-04 - val_mae: 0.0155
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# GRU-64-32 RMSE (Close): 442.8219, MAE (Close): 369.0430, Time: 16.9s
#
# ==================================================
# Training model: GRU-128-64-32
# Epoch 1/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 0.0065 - mae: 0.0573 - val_loss: 0.0024 - val_mae: 0.0467
# Epoch 2/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.9278e-04 - mae: 0.0203 - val_loss: 8.7735e-04 - val_mae: 0.0269
# Epoch 3/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.6776e-04 - mae: 0.0181 - val_loss: 1.8620e-04 - val_mae: 0.0107
# Epoch 4/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.1856e-04 - mae: 0.0179 - val_loss: 9.5776e-04 - val_mae: 0.0282
# Epoch 5/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.6975e-04 - mae: 0.0172 - val_loss: 2.4858e-04 - val_mae: 0.0133
# Epoch 6/20
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.0050e-04 - mae: 0.0156 - val_loss: 2.4843e-04 - val_mae: 0.0118
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# GRU-128-64-32 RMSE (Close): 378.2539, MAE (Close): 300.3278, Time: 9.7s
# Best model by RMSE (Close): GRU-32 {'rmse': 243.51880060890576, 'mae': 189.51931762695312}
# === Summary Table (sorted by RMSE) ===
#             Model         RMSE          MAE  Training Time (s)
# 6          GRU-32   243.518801   189.519318                6.1
# 3         LSTM-32   294.350463   230.045914                8.2
# 8   GRU-128-64-32   378.253904   300.327820                9.7
# 7       GRU-64-32   442.821917   369.043030               16.9
# 4      LSTM-64-32  1180.049893  1029.808838                6.0
# 5  LSTM-128-64-32  1528.075587  1365.128296                9.2
# 0          RNN-32  2304.216136  2033.334595                9.1
# 1       RNN-64-32  2332.873443  2100.768799               20.3
# 2   RNN-128-64-32  4270.129740  3880.313721               18.5
#
# Teaching progression notes:
# 1) Start with raw plot + decomposition -> motivate stationarity/trend/seasonality.
# 2) Show the effect of scaling and why sequences are needed.
# 3) Train small RNN/LSTM/GRU (32 units) — quick results to show model shapes.
# 4) Increase depth & units (64->32, 128->64->32) and discuss capacity vs overfitting.
# 5) Show validation loss curves and explain EarlyStopping.
# 6) Show runtime differences (RNN < GRU < LSTM typically).
# 7) Demonstrate forecasting quality (RMSE/MAE) and error/residual analysis.
#
# Key concepts to explain:
# - Why we use sequential data (time steps)
# - How RNN/LSTM/GRU differ in architecture
# - The role of dropout in preventing overfitting
# - How scaling helps with gradient stability
# - Why we use early stopping
# - How to interpret RMSE and MAE in context of stock prices
